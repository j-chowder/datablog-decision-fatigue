# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/data.csv')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  str
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  str
#  6   winner          20058 non-null  str
#  7   increment_code  20058 non-null  str
#  8   white_id        20058 non-null  str
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  str
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  str
#  13  opening_eco     20058 non-null  str
#  14  opening_name    20058 non-null  str
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), str(9)
# memory usage: 2.3 MB

# %%
np.mean(df['turns'])
# Out:
# np.float64(60.46599860404826)

# %%
start_idx = df.index[df['id'] == '8c3usY4b'][0]
result = df.loc[start_idx:]

# %%
result.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6380 entries, 13678 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              6380 non-null   str
#  1   rated           6380 non-null   bool
#  2   created_at      6380 non-null   float64
#  3   last_move_at    6380 non-null   float64
#  4   turns           6380 non-null   int64
#  5   victory_status  6380 non-null   str
#  6   winner          6380 non-null   str
#  7   increment_code  6380 non-null   str
#  8   white_id        6380 non-null   str
#  9   white_rating    6380 non-null   int64
#  10  black_id        6380 non-null   str
#  11  black_rating    6380 non-null   int64
#  12  moves           6380 non-null   str
#  13  opening_eco     6380 non-null   str
#  14  opening_name    6380 non-null   str
#  15  opening_ply     6380 non-null   int64
# dtypes: bool(1), float64(2), int64(4), str(9)
# memory usage: 754.0 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  str
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  str
#  6   winner          20058 non-null  str
#  7   increment_code  20058 non-null  str
#  8   white_id        20058 non-null  str
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  str
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  str
#  13  opening_eco     20058 non-null  str
#  14  opening_name    20058 non-null  str
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), str(9)
# memory usage: 2.3 MB
